# %% [markdown]
# <h3>Text Analytics</h3>
# <hr>
# <p>1. Extract Sample document and apply following document preprocessing methods: Tokenization, POS Tagging, Stop words removal, Stemming and Lemmatization.</p>
# <p>2. Create representation of document by calculating Term Frequency and Inverse Document Frequency.</p>
# <p>
# <hr>
# <b>Name:</b> Udayan Chavan
# <b>Roll no:</b> 31117
# <b>Batch:</b> K1
# </p>

# %% [markdown]
# <b>Importing the necessary libraries</b>

# %%
import pandas as pd
import numpy as np

import spacy
nlp = spacy.load('en_core_web_sm')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <b> Loading and Tokenizing file </b>

# %%
#text = open("testdoc.txt", "r")

with open('testdoc.txt', 'r') as file:
    text = file.read()

doc = nlp(text)

# Creating tokens
print([token.text for token in doc])
print("\nLength of Document:", len(doc))
# Out:
# ['Harley', '-', 'Davidson', ',', 'Inc.', ',', 'H', '-', 'D', ',', 'or', 'Harley', ',', 'is', 'an', 'American', 'motorcycle', 'manufacturer', 'founded', 'in', '1903', 'in', 'Milwaukee', ',', 'Wisconsin', '.', 'Along', 'with', 'Indian', ',', 'it', 'was', 'one', 'of', 'two', 'major', 'American', 'motorcycle', 'manufacturers', 'to', 'survive', 'the', 'Great', 'Depression', '.', 'The', 'company', 'has', 'survived', 'numerous', 'ownership', 'arrangements', ',', 'subsidiary', 'arrangements', ',', 'periods', 'of', 'poor', 'economic', 'health', 'and', 'product', 'quality', ',', 'and', 'intense', 'global', 'competition', 'to', 'become', 'one', 'of', 'the', 'world', "'s", 'largest', 'motorcycle', 'manufacturers', 'and', 'an', 'iconic', 'brand', 'widely', 'known', 'for', 'its', 'loyal', 'following', '.', 'There', 'are', 'owner', 'clubs', 'and', 'events', 'worldwide', ',', 'as', 'well', 'as', 'a', 'company', '-', 'sponsored', ',', 'brand', '-', 'focused', 'museum', '.', '\n\n', 'Harley', '-', 'Da
# ...

# %%
sentences = list(doc.sents)
print("Number of sentences:", len(sentences))
# Out:
# Number of sentences: 9

# %%
print("TOKEN INDEX IS_SPACE IS_PUNCT IS_STOP SHAPE")
for token in doc:
    print("\n", token.text, token.idx, token.is_space, token.is_punct, token.is_stop, token.shape_)
# Out:
# TOKEN INDEX IS_SPACE IS_PUNCT IS_STOP SHAPE
#
#  Harley 0 False False False Xxxxx
#
#  - 6 False True False -
#
#  Davidson 7 False False False Xxxxx
#
#  , 15 False True False ,
#
#  Inc. 17 False False False Xxx.
#
#  , 21 False True False ,
#
#  H 23 False False False X
#
#  - 24 False True False -
#
#  D 25 False False False X
#
#  , 26 False True False ,
#
#  or 28 False False True xx
#
#  Harley 31 False False False Xxxxx
#
#  , 37 False True False ,
#
#  is 39 False False True xx
#
#  an 42 False False True xx
#
#  American 45 False False False Xxxxx
#
#  motorcycle 54 False False False xxxx
#
#  manufacturer 65 False False False xxxx
#
#  founded 78 False False False xxxx
#
#  in 86 False False True xx
#
#  1903 89 False False False dddd
#
#  in 94 False False True xx
#
#  Milwaukee 97 False False False Xxxxx
#
#  , 106 False True False ,
#
#  Wisconsin 108 False False False Xxxxx
#
#  . 117 False True False .
#
#  Along 119 False False True Xxxxx
#
# ...

# %% [markdown]
# <b>Stop words:</b> Words that don't add any valuable information to text analytics and are usually removed during preprocessing.

# %%
spacy_stopwords = spacy.lang.en.stop_words.STOP_WORDS
print("Total stop words:", len(spacy_stopwords))
# Out:
# Total stop words: 326

# %%
words = [word.lemma_ for word in doc]
print(words)
# Out:
# ['Harley', '-', 'Davidson', ',', 'Inc.', ',', 'H', '-', 'D', ',', 'or', 'Harley', ',', 'be', 'an', 'american', 'motorcycle', 'manufacturer', 'found', 'in', '1903', 'in', 'Milwaukee', ',', 'Wisconsin', '.', 'along', 'with', 'Indian', ',', 'it', 'be', 'one', 'of', 'two', 'major', 'american', 'motorcycle', 'manufacturer', 'to', 'survive', 'the', 'Great', 'Depression', '.', 'the', 'company', 'have', 'survive', 'numerous', 'ownership', 'arrangement', ',', 'subsidiary', 'arrangement', ',', 'period', 'of', 'poor', 'economic', 'health', 'and', 'product', 'quality', ',', 'and', 'intense', 'global', 'competition', 'to', 'become', 'one', 'of', 'the', 'world', "'s", 'large', 'motorcycle', 'manufacturer', 'and', 'an', 'iconic', 'brand', 'widely', 'know', 'for', 'its', 'loyal', 'following', '.', 'there', 'be', 'owner', 'club', 'and', 'event', 'worldwide', ',', 'as', 'well', 'as', 'a', 'company', '-', 'sponsor', ',', 'brand', '-', 'focus', 'museum', '.', '\n\n', 'Harley', '-', 'Davidson', 'be', 'no
# ...

# %% [markdown]
# Adding all the non stop words to another list

# %%
vocabulary = []
vocabulary = " ".join([word.lemma_ for word in doc if word not in spacy_stopwords])
print(vocabulary)
# Out:
# Harley - Davidson , Inc. , H - D , or Harley , be an american motorcycle manufacturer found in 1903 in Milwaukee , Wisconsin . along with Indian , it be one of two major american motorcycle manufacturer to survive the Great Depression . the company have survive numerous ownership arrangement , subsidiary arrangement , period of poor economic health and product quality , and intense global competition to become one of the world 's large motorcycle manufacturer and an iconic brand widely know for its loyal following . there be owner club and event worldwide , as well as a company - sponsor , brand - focus museum .
#
#  Harley - Davidson be note for a style of customization that give rise to the chopper motorcycle style . the company traditionally market heavyweight , air - cool cruiser motorcycle with engine displacement great than 700 cc , but it have broaden its offering to include more contemporary VRSC ( 2002 ) and middle - weight Street ( 2015 ) platform .
#
# ...

# %%
for token in doc:
    print(token, token.pos_)
# Out:
# Harley PROPN
# - PUNCT
# Davidson PROPN
# , PUNCT
# Inc. PROPN
# , PUNCT
# H PROPN
# - PUNCT
# D PROPN
# , PUNCT
# or CCONJ
# Harley PROPN
# , PUNCT
# is AUX
# an DET
# American ADJ
# motorcycle NOUN
# manufacturer NOUN
# founded VERB
# in ADP
# 1903 NUM
# in ADP
# Milwaukee PROPN
# , PUNCT
# Wisconsin PROPN
# . PUNCT
# Along ADP
# with ADP
# Indian PROPN
# , PUNCT
# it PRON
# was AUX
# one NUM
# of ADP
# two NUM
# major ADJ
# American ADJ
# motorcycle NOUN
# manufacturers NOUN
# to PART
# survive VERB
# the DET
# Great PROPN
# Depression PROPN
# . PUNCT
# The DET
# company NOUN
# has AUX
# survived VERB
# numerous ADJ
# ownership NOUN
# arrangements NOUN
# , PUNCT
# subsidiary NOUN
# arrangements NOUN
# , PUNCT
# periods NOUN
# of ADP
# poor ADJ
# economic ADJ
# health NOUN
# and CCONJ
# product NOUN
# quality NOUN
# , PUNCT
# and CCONJ
# intense ADJ
# global ADJ
# competition NOUN
# to PART
# become VERB
# one NUM
# of ADP
# the DET
# world NOUN
# 's PART
# largest ADJ
# ...

# %% [markdown]
# Extracting nouns and verbs

# %%
verbs = [token.text for token in doc if token.pos_ == "VERB"]
nouns = [token.text for token in doc if token.pos_ == "NOUN"]

print('Verb count:', len(verbs))
print('Noun count:', len(nouns))
print("-"*124)

print("Verbs: ", verbs)
print("-"*124)
print("Nouns: ", nouns)
# Out:
# Verb count: 17
# Noun count: 63
# ----------------------------------------------------------------------------------------------------------------------------
# Verbs:  ['founded', 'survive', 'survived', 'become', 'known', 'are', 'sponsored', 'focused', 'noted', 'gave', 'marketed', 'cooled', 'broadened', 'include', 'manufactures', 'markets', 'based']
# ----------------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Printing token and token lemma (base form of token)

# %%
for token in doc:
    print(token, token.lemma_)
# Out:
# Harley Harley
# - -
# Davidson Davidson
# , ,
# Inc. Inc.
# , ,
# H H
# - -
# D D
# , ,
# or or
# Harley Harley
# , ,
# is be
# an an
# American american
# motorcycle motorcycle
# manufacturer manufacturer
# founded found
# in in
# 1903 1903
# in in
# Milwaukee Milwaukee
# , ,
# Wisconsin Wisconsin
# . .
# Along along
# with with
# Indian Indian
# , ,
# it it
# was be
# one one
# of of
# two two
# major major
# American american
# motorcycle motorcycle
# manufacturers manufacturer
# to to
# survive survive
# the the
# Great Great
# Depression Depression
# . .
# The the
# company company
# has have
# survived survive
# numerous numerous
# ownership ownership
# arrangements arrangement
# , ,
# subsidiary subsidiary
# arrangements arrangement
# , ,
# periods period
# of of
# poor poor
# economic economic
# health health
# and and
# product product
# quality quality
# , ,
# and and
# intense intense
# global global
# competition competition
# to to
# become become
# one one
# of of
# ...

# %% [markdown]
# <b>Stemming:</b> A process that lowers the inflection of words to their lowest form.

# %%
import nltk
from nltk.stem import WordNetLemmatizer, PorterStemmer

# %%
words = []

words = " ".join(token.text for token in doc)
words
# Out:
# "Harley - Davidson , Inc. , H - D , or Harley , is an American motorcycle manufacturer founded in 1903 in Milwaukee , Wisconsin . Along with Indian , it was one of two major American motorcycle manufacturers to survive the Great Depression . The company has survived numerous ownership arrangements , subsidiary arrangements , periods of poor economic health and product quality , and intense global competition to become one of the world 's largest motorcycle manufacturers and an iconic brand widely known for its loyal following . There are owner clubs and events worldwide , as well as a company - sponsored , brand - focused museum . \n\n Harley - Davidson is noted for a style of customization that gave rise to the chopper motorcycle style . The company traditionally marketed heavyweight , air - cooled cruiser motorcycles with engine displacements greater than 700 cc , but it has broadened its offerings to include more contemporary VRSC ( 2002 ) and middle - weight Street ( 2015 ) platf
# ...

# %%
ps = PorterStemmer()
stemmed_words = []
for token in doc:
    stemmed_words.append(ps.stem(token.text))
    
stemmed_words
# Out:
# ['harley',
#  '-',
#  'davidson',
#  ',',
#  'inc.',
#  ',',
#  'h',
#  '-',
#  'd',
#  ',',
#  'or',
#  'harley',
#  ',',
#  'is',
#  'an',
#  'american',
#  'motorcycl',
#  'manufactur',
#  'found',
#  'in',
#  '1903',
#  'in',
#  'milwauke',
#  ',',
#  'wisconsin',
#  '.',
#  'along',
#  'with',
#  'indian',
#  ',',
#  'it',
#  'wa',
#  'one',
#  'of',
#  'two',
#  'major',
#  'american',
#  'motorcycl',
#  'manufactur',
#  'to',
#  'surviv',
#  'the',
#  'great',
#  'depress',
#  '.',
#  'the',
#  'compani',
#  'ha',
#  'surviv',
#  'numer',
#  'ownership',
#  'arrang',
#  ',',
#  'subsidiari',
#  'arrang',
#  ',',
#  'period',
#  'of',
#  'poor',
#  'econom',
#  'health',
#  'and',
#  'product',
#  'qualiti',
#  ',',
#  'and',
#  'intens',
#  'global',
#  'competit',
#  'to',
#  'becom',
#  'one',
#  'of',
#  'the',
#  'world',
#  "'s",
#  'largest',
#  'motorcycl',
#  'manufactur',
#  'and',
#  'an',
#  'icon',
#  'brand',
#  'wide',
#  'known',
#  'for',
#  'it',
#  'loyal',
# ...

# %%
wl = WordNetLemmatizer()
wl_stemmed_words = []
for token in doc:
    wl_stemmed_words.append(wl.lemmatize(token.text))
wl_stemmed_words
# Out:
# ['Harley',
#  '-',
#  'Davidson',
#  ',',
#  'Inc.',
#  ',',
#  'H',
#  '-',
#  'D',
#  ',',
#  'or',
#  'Harley',
#  ',',
#  'is',
#  'an',
#  'American',
#  'motorcycle',
#  'manufacturer',
#  'founded',
#  'in',
#  '1903',
#  'in',
#  'Milwaukee',
#  ',',
#  'Wisconsin',
#  '.',
#  'Along',
#  'with',
#  'Indian',
#  ',',
#  'it',
#  'wa',
#  'one',
#  'of',
#  'two',
#  'major',
#  'American',
#  'motorcycle',
#  'manufacturer',
#  'to',
#  'survive',
#  'the',
#  'Great',
#  'Depression',
#  '.',
#  'The',
#  'company',
#  'ha',
#  'survived',
#  'numerous',
#  'ownership',
#  'arrangement',
#  ',',
#  'subsidiary',
#  'arrangement',
#  ',',
#  'period',
#  'of',
#  'poor',
#  'economic',
#  'health',
#  'and',
#  'product',
#  'quality',
#  ',',
#  'and',
#  'intense',
#  'global',
#  'competition',
#  'to',
#  'become',
#  'one',
#  'of',
#  'the',
#  'world',
#  "'s",
#  'largest',
#  'motorcycle',
#  'manufacturer',
#  'and',
#  'an',
#  'iconic',
#  'brand',
#  'widely',
# ...

# %% [markdown]
# <b>Term Frequency:</b> (Number of occurences of a word) / (Total number of words)

# %%
corpus = [text]
def termfreq(corpus):
    dic = {}
    
    for doc in corpus:
        for word in doc.split():
            if word in dic:
                dic[word]+=1
            else:
                dic[word]=1
                
    for word, freq in dic.items():
        print(word, freq)
        dic[word] = freq / len(doc)
        
    print("Document size in number of words:", len(doc))
    return dic

termfreq(corpus)
# Out:
# Harley-Davidson, 1
# Inc., 1
# H-D, 1
# or 1
# Harley, 1
# is 2
# an 2
# American 2
# motorcycle 5
# manufacturer 1
# founded 1
# in 3
# 1903 1
# Milwaukee, 2
# Wisconsin. 1
# Along 1
# with 2
# Indian, 1
# it 2
# was 1
# one 2
# of 5
# two 1
# major 1
# manufacturers 2
# to 4
# survive 1
# the 5
# Great 1
# Depression. 1
# The 3
# company 3
# has 2
# survived 1
# numerous 1
# ownership 1
# arrangements, 2
# subsidiary 1
# periods 1
# poor 1
# economic 1
# health 1
# and 11
# product 1
# quality, 1
# intense 1
# global 1
# competition 1
# become 1
# world's 1
# largest 1
# iconic 1
# brand 1
# widely 1
# known 1
# for 2
# its 6
# loyal 1
# following. 1
# There 1
# are 1
# owner 1
# clubs 1
# events 1
# worldwide, 2
# as 2
# well 1
# a 2
# company-sponsored, 1
# brand-focused 1
# museum. 1
# Harley-Davidson 3
# noted 1
# style 1
# customization 1
# that 1
# gave 1
# rise 1
# chopper 1
# style. 1
# traditionally 1
# marketed 1
# heavyweight, 1
# air-cooled 1
# cruiser 1
# ...

# %% [markdown]
# <p><b>IDF:</b> Inverse Data Frequency</p>
# <p>
# It is a measure of whether a term is common or rare in a given document corpus. The words that occur commonly have a high tf-idf score.

# %%
import re
import nltk
from nltk.corpus import stopwords

doc_text = " "

def preprocess_docs(text):
    text = str(text).lower()
    text = re.sub('[^a-zA-z0-9\s]','',str(text))
    text = text.split()
    
    text = [wl.lemmatize(word) for word in text if not word in stopwords.words("english")]
    new_text = " ".join(text)
    
    return new_text

corpus = [text]
text1 = preprocess_docs(text)

print(text1)
# Out:
# harleydavidson inc hd harley american motorcycle manufacturer founded 1903 milwaukee wisconsin along indian one two major american motorcycle manufacturer survive great depression company survived numerous ownership arrangement subsidiary arrangement period poor economic health product quality intense global competition become one world largest motorcycle manufacturer iconic brand widely known loyal following owner club event worldwide well companysponsored brandfocused museum harleydavidson noted style customization gave rise chopper motorcycle style company traditionally marketed heavyweight aircooled cruiser motorcycle engine displacement greater 700 cc broadened offering include contemporary vrsc 2002 middleweight street 2015 platform harleydavidson manufacture motorcycle factory york pennsylvania milwaukee wisconsin manaus brazil bawal india pluak daeng thailand company market product worldwide also license market merchandise harleydavidson brand among apparel home dcor ornament
# ...

# %%
first = text1
first = first.split(" ")

total = set(first)

wordDict = dict.fromkeys(total, 0)

for word in first:
    wordDict[word] += 1
    
pd.DataFrame([wordDict])
# Out:
#    event  company  thailand  known  model  health  wisconsin  gave  apparel  \
# 0      1        3         1      1      1       1          2     1        1
#
#    cc  ...  poor  become  numerous  license  museum  survived  customization  \
# 0   1  ...     1       1         1        1       1         1              1
#
#    york  inc  among
# 0     1    1      1
#
# [1 rows x 106 columns]

# %%
def computeTF(wordDict, bow):
    tfDict = {}
    bowCount = len(bow)
    
    for word, count in wordDict.items():
        tfDict[word] = count / float(bowCount)
        
    return tfDict

tf = computeTF(wordDict, first)
tf_df = pd.DataFrame([tf])
tf_df.head()
# Out:
#       event   company  thailand     known     model    health  wisconsin  \
# 0  0.007692  0.023077  0.007692  0.007692  0.007692  0.007692   0.015385
#
#        gave   apparel        cc  ...      poor    become  numerous   license  \
# 0  0.007692  0.007692  0.007692  ...  0.007692  0.007692  0.007692  0.007692
#
#      museum  survived  customization      york       inc     among
# 0  0.007692  0.007692       0.007692  0.007692  0.007692  0.007692
#
# [1 rows x 106 columns]

# %%
def ComputeIDF(docList):
    idfDict = {}
    N = len(docList)
    
    idfDict = dict.fromKeys(docList[0].keys(), 0)
    for doc in docList:
        for word, val in doc.items():
            if val > 0:
                idfDict[word] += 1

    for word, val in idfDict.items():
        idfDict[word] = math.log10(N / float(val))

    return idfDict

idfs = computeIDF([wordDictA, wordDictB])
